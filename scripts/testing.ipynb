# %%
import tdtomo
# Out:
# 2026-03-21 18:07:14,926 - INFO - CuPy is available. 1 GPU devices detected.
# 2026-03-21 18:07:15,078 - DEBUG - Updating registry with hook 'is_tomobase_phantom' (explicit=False)
# 2026-03-21 18:07:15,079 - DEBUG - Scanning C:\Users\tcrai\Documents\Code\Python\wspace-tdtomo\TimeDependentTomography\submodules\tomobase\tomobase for is_tomobase_phantom items
# 2026-03-21 18:07:15,081 - DEBUG - Importing tomobase.environment to check for is_tomobase_phantom items
# 2026-03-21 18:07:15,081 - DEBUG - Importing tomobase.log to check for is_tomobase_phantom items
# 2026-03-21 18:07:15,081 - DEBUG - Importing tomobase.utils to check for is_tomobase_phantom items
# 2026-03-21 18:07:15,162 - DEBUG - Importing tomobase.__init__ to check for is_tomobase_phantom items
# 2026-03-21 18:07:15,164 - DEBUG - Added category 'Acquistion' -> 0x3c00000000 (inheritor=None)
# 2026-03-21 18:07:15,165 - DEBUG - Added category 'Tomography' -> 0x4400000000 (inheritor=None)
# ...
